# %%
arr = [1,12,3,4,5,8,9]

# %%
def is_sorted(a,k=0):
    if len(a)==1:
        return True    
    return a[k] < a[k+1] and is_sorted(a[k+1:])

# %%
is_sorted(arr)
# Out:
# False

# %%
print('hello yuva') #sai
# Out:
# hello yuva
