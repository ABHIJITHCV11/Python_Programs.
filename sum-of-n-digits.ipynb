# %%
def s(n):
    if n == 0:
        return 0
    else:
        return n + s(n-1)

# %%
s(0)
# Out:
# 0

# %%
s(1)
# Out:
# 1

# %%
s(2)
# Out:
# 3

# %%
s(3)
# Out:
# 6

# %%
s(4)
# Out:
# 10

# %%
s(5)
# Out:
# 15

# %%
s(6)
# Out:
# 21
