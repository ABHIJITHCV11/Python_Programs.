# %%
def s(n,x=0): # x=0 so that we need not give argument 2.
    if n % 10 == 0:
        return x
    x = x + n%10
    return s(n//10,x)

# %%
s(0,0)
# Out:
# 0

# %%
s(123)
# Out:
# 6

# %%
s(1234,0)
# Out:
# 10
