# %%
def n_to_0_then_0_to_n(n):
    print(n)
    if n == 0:
        return None
    n_to_0_then_0_to_n(n-1)
    print(n)
    return None

# %%
n_to_0_then_0_to_n(4)
# Out:
# 4
# 3
# 2
# 1
# 0
# 1
# 2
# 3
# 4

# %%
# n  --> 4
# 4,3,2,1,0,1,2,3,4
